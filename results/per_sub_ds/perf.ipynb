# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('result.txt', sep=',')
df = df.round(3)
df
# Out:
#       Dataset   Method    mae   max-feature   mean-fmeasure   adp-fmeasure  \
# 0        High    DANet  0.048         0.888           0.862          0.860
# 1        High   DFMNet  0.047         0.890           0.873          0.874
# 2        High   JL-DCF  0.048         0.888           0.874          0.873
# 3        High    UCNet  0.047         0.878           0.860          0.861
# 4         Low    DANet  0.071         0.881           0.859          0.850
# 5         Low   DFMNet  0.070         0.873           0.861          0.864
# 6         Low   JL-DCF  0.061         0.892           0.879          0.879
# 7         Low    UCNet  0.073         0.849           0.842          0.848
# 8       Multi    DANet  0.074         0.876           0.856          0.854
# 9       Multi   DFMNet  0.079         0.866           0.852          0.861
# 10      Multi   JL-DCF  0.081         0.864           0.855          0.862
# ...

# %%
cat = df[df['Dataset'] == 'complex'].reset_index()
cat
# Out:
#    index  Dataset   Method    mae   max-feature   mean-fmeasure  \
# 0     16  complex    DANet  0.068         0.757           0.732
# 1     17  complex   DFMNet  0.070         0.760           0.728
# 2     18  complex   JL-DCF  0.070         0.777           0.752
# 3     19  complex    UCNet  0.065         0.774           0.764
#
#     adp-fmeasure   max-Emeasure   mean-Emeasure   adp-Emeasure  \
# 0          0.684          0.857           0.841          0.819
# 1          0.707          0.857           0.841          0.812
# 2          0.733          0.865           0.850          0.816
# 3          0.759          0.862           0.858          0.840
#
#     S-measure_alpha05   Fbw-measure
# 0               0.820         0.673
# 1               0.819         0.669
# 2               0.826         0.701
# 3               0.826         0.719

# %%
plt.scatter(cat[' S-measure_alpha05'][0], cat[' max-feature'][0], label='DANet', s=104)
plt.scatter(cat[' S-measure_alpha05'][1], cat[' max-feature'][1], label='DFMNet', s=9)
plt.scatter(cat[' S-measure_alpha05'][2], cat[' max-feature'][2], label='JL-DCF', s=561)
plt.scatter(cat[' S-measure_alpha05'][3], cat[' max-feature'][3], label='UCNet', s=123)
# plt.scatter(cat[' S-measure_alpha05'][0], cat[' max-feature'][0], label='DANet')
# plt.scatter(cat[' S-measure_alpha05'][1], cat[' max-feature'][1], label='DFMNet')
# plt.scatter(cat[' S-measure_alpha05'][2], cat[' max-feature'][2], label='JL-DCF')
# plt.scatter(cat[' S-measure_alpha05'][3], cat[' max-feature'][3], label='UCNet')
plt.annotate("DANet", (cat[' S-measure_alpha05'][0], cat[' max-feature'][0]))
plt.annotate("DFMNet", (cat[' S-measure_alpha05'][1], cat[' max-feature'][1]))
plt.annotate("JL-DCF", (cat[' S-measure_alpha05'][2], cat[' max-feature'][2]))
plt.annotate("UCNet", (cat[' S-measure_alpha05'][3], cat[' max-feature'][3]))
plt.ylabel("Accuracy (maxF-measure)")
plt.xlabel("Structure similarity")
plt.title("High")
plt.grid()
plt.show()

# %%
plt.scatter(cat[' S-measure_alpha05'][0], cat[' max-feature'][0], label='DANet', s=104)
plt.scatter(cat[' S-measure_alpha05'][1], cat[' max-feature'][1], label='DFMNet', s=9)
plt.scatter(cat[' S-measure_alpha05'][2], cat[' max-feature'][2], label='JL-DCF', s=561)
plt.scatter(cat[' S-measure_alpha05'][3], cat[' max-feature'][3], label='UCNet', s=123)
# plt.scatter(cat[' S-measure_alpha05'][0], cat[' max-feature'][0], label='DANet')
# plt.scatter(cat[' S-measure_alpha05'][1], cat[' max-feature'][1], label='DFMNet')
# plt.scatter(cat[' S-measure_alpha05'][2], cat[' max-feature'][2], label='JL-DCF')
# plt.scatter(cat[' S-measure_alpha05'][3], cat[' max-feature'][3], label='UCNet')
plt.annotate("DANet", (cat[' S-measure_alpha05'][0], cat[' max-feature'][0]))
plt.annotate("DFMNet", (cat[' S-measure_alpha05'][1], cat[' max-feature'][1]))
plt.annotate("JL-DCF", (cat[' S-measure_alpha05'][2], cat[' max-feature'][2]))
plt.annotate("UCNet", (cat[' S-measure_alpha05'][3], cat[' max-feature'][3]))
plt.ylabel("Accuracy (maxF-measure)")
plt.xlabel("Structure similarity")
plt.title("Low")
plt.grid()
plt.show()

# %%
plt.scatter(cat[' S-measure_alpha05'][0], cat[' max-feature'][0], label='DANet', s=104)
plt.scatter(cat[' S-measure_alpha05'][1], cat[' max-feature'][1], label='DFMNet', s=9)
plt.scatter(cat[' S-measure_alpha05'][2], cat[' max-feature'][2], label='JL-DCF', s=561)
plt.scatter(cat[' S-measure_alpha05'][3], cat[' max-feature'][3], label='UCNet', s=123)
# plt.scatter(cat[' S-measure_alpha05'][0], cat[' max-feature'][0], label='DANet')
# plt.scatter(cat[' S-measure_alpha05'][1], cat[' max-feature'][1], label='DFMNet')
# plt.scatter(cat[' S-measure_alpha05'][2], cat[' max-feature'][2], label='JL-DCF')
# plt.scatter(cat[' S-measure_alpha05'][3], cat[' max-feature'][3], label='UCNet')
plt.annotate("DANet", (cat[' S-measure_alpha05'][0], cat[' max-feature'][0]))
plt.annotate("DFMNet", (cat[' S-measure_alpha05'][1], cat[' max-feature'][1]))
plt.annotate("JL-DCF", (cat[' S-measure_alpha05'][2], cat[' max-feature'][2]))
plt.annotate("UCNet", (cat[' S-measure_alpha05'][3], cat[' max-feature'][3]))
plt.ylabel("Accuracy (maxF-measure)")
plt.xlabel("Structure similarity")
plt.title("small")
plt.grid()
plt.show()

# %%
plt.scatter(cat[' S-measure_alpha05'][0], cat[' max-feature'][0], label='DANet', s=104)
plt.scatter(cat[' S-measure_alpha05'][1], cat[' max-feature'][1], label='DFMNet', s=9)
plt.scatter(cat[' S-measure_alpha05'][2], cat[' max-feature'][2], label='JL-DCF', s=561)
plt.scatter(cat[' S-measure_alpha05'][3], cat[' max-feature'][3], label='UCNet', s=123)
# plt.scatter(cat[' S-measure_alpha05'][0], cat[' max-feature'][0], label='DANet')
# plt.scatter(cat[' S-measure_alpha05'][1], cat[' max-feature'][1], label='DFMNet')
# plt.scatter(cat[' S-measure_alpha05'][2], cat[' max-feature'][2], label='JL-DCF')
# plt.scatter(cat[' S-measure_alpha05'][3], cat[' max-feature'][3], label='UCNet')
plt.annotate("DANet", (cat[' S-measure_alpha05'][0]-0.003, cat[' max-feature'][0]-0.002))
plt.annotate("DFMNet", (cat[' S-measure_alpha05'][1], cat[' max-feature'][1]))
plt.annotate("JL-DCF", (cat[' S-measure_alpha05'][2], cat[' max-feature'][2]))
plt.annotate("UCNet", (cat[' S-measure_alpha05'][3], cat[' max-feature'][3]))
plt.ylabel("Accuracy (maxF-measure)")
plt.xlabel("Structure similarity")
plt.title("medium")
plt.grid()
plt.show()

# %%
plt.scatter(cat[' S-measure_alpha05'][0], cat[' max-feature'][0], label='DANet', s=104)
plt.scatter(cat[' S-measure_alpha05'][1], cat[' max-feature'][1], label='DFMNet', s=9)
plt.scatter(cat[' S-measure_alpha05'][2], cat[' max-feature'][2], label='JL-DCF', s=561)
plt.scatter(cat[' S-measure_alpha05'][3], cat[' max-feature'][3], label='UCNet', s=123)
# plt.scatter(cat[' S-measure_alpha05'][0], cat[' max-feature'][0], label='DANet')
# plt.scatter(cat[' S-measure_alpha05'][1], cat[' max-feature'][1], label='DFMNet')
# plt.scatter(cat[' S-measure_alpha05'][2], cat[' max-feature'][2], label='JL-DCF')
# plt.scatter(cat[' S-measure_alpha05'][3], cat[' max-feature'][3], label='UCNet')
plt.annotate("DANet", (cat[' S-measure_alpha05'][0], cat[' max-feature'][0]))
plt.annotate("DFMNet", (cat[' S-measure_alpha05'][1], cat[' max-feature'][1]))
plt.annotate("JL-DCF", (cat[' S-measure_alpha05'][2], cat[' max-feature'][2]))
plt.annotate("UCNet", (cat[' S-measure_alpha05'][3], cat[' max-feature'][3]))
plt.ylabel("Accuracy (maxF-measure)")
plt.xlabel("Structure similarity")
plt.title("large")
plt.grid()
plt.show()

# %%
plt.scatter(cat[' S-measure_alpha05'][0], cat[' max-feature'][0], label='DANet', s=104)
plt.scatter(cat[' S-measure_alpha05'][1], cat[' max-feature'][1], label='DFMNet', s=9)
plt.scatter(cat[' S-measure_alpha05'][2], cat[' max-feature'][2], label='JL-DCF', s=561)
plt.scatter(cat[' S-measure_alpha05'][3], cat[' max-feature'][3], label='UCNet', s=123)
# plt.scatter(cat[' S-measure_alpha05'][0], cat[' max-feature'][0], label='DANet')
# plt.scatter(cat[' S-measure_alpha05'][1], cat[' max-feature'][1], label='DFMNet')
# plt.scatter(cat[' S-measure_alpha05'][2], cat[' max-feature'][2], label='JL-DCF')
# plt.scatter(cat[' S-measure_alpha05'][3], cat[' max-feature'][3], label='UCNet')
plt.annotate("DANet", (cat[' S-measure_alpha05'][0], cat[' max-feature'][0]))
plt.annotate("DFMNet", (cat[' S-measure_alpha05'][1], cat[' max-feature'][1]))
plt.annotate("JL-DCF", (cat[' S-measure_alpha05'][2], cat[' max-feature'][2]))
plt.annotate("UCNet", (cat[' S-measure_alpha05'][3], cat[' max-feature'][3]))
plt.ylabel("Accuracy (maxF-measure)")
plt.xlabel("Structure similarity")
plt.title("simple")
plt.grid()
plt.show()

# %%
plt.scatter(cat[' S-measure_alpha05'][0], cat[' max-feature'][0], label='DANet', s=104)
plt.scatter(cat[' S-measure_alpha05'][1], cat[' max-feature'][1], label='DFMNet', s=9)
plt.scatter(cat[' S-measure_alpha05'][2], cat[' max-feature'][2], label='JL-DCF', s=561)
plt.scatter(cat[' S-measure_alpha05'][3], cat[' max-feature'][3], label='UCNet', s=123)
# plt.scatter(cat[' S-measure_alpha05'][0], cat[' max-feature'][0], label='DANet')
# plt.scatter(cat[' S-measure_alpha05'][1], cat[' max-feature'][1], label='DFMNet')
# plt.scatter(cat[' S-measure_alpha05'][2], cat[' max-feature'][2], label='JL-DCF')
# plt.scatter(cat[' S-measure_alpha05'][3], cat[' max-feature'][3], label='UCNet')
plt.annotate("DANet", (cat[' S-measure_alpha05'][0], cat[' max-feature'][0]))
plt.annotate("DFMNet", (cat[' S-measure_alpha05'][1], cat[' max-feature'][1]))
plt.annotate("JL-DCF", (cat[' S-measure_alpha05'][2], cat[' max-feature'][2]))
plt.annotate("UCNet", (cat[' S-measure_alpha05'][3], cat[' max-feature'][3]))
plt.ylabel("Accuracy (maxF-measure)")
plt.xlabel("Structure similarity")
plt.title("uncertain")
plt.grid()
plt.show()

# %%
plt.scatter(cat[' S-measure_alpha05'][0], cat[' max-feature'][0], label='DANet', s=104)
plt.scatter(cat[' S-measure_alpha05'][1], cat[' max-feature'][1], label='DFMNet', s=9)
plt.scatter(cat[' S-measure_alpha05'][2], cat[' max-feature'][2], label='JL-DCF', s=561)
plt.scatter(cat[' S-measure_alpha05'][3], cat[' max-feature'][3], label='UCNet', s=123)
# plt.scatter(cat[' S-measure_alpha05'][0], cat[' max-feature'][0], label='DANet')
# plt.scatter(cat[' S-measure_alpha05'][1], cat[' max-feature'][1], label='DFMNet')
# plt.scatter(cat[' S-measure_alpha05'][2], cat[' max-feature'][2], label='JL-DCF')
# plt.scatter(cat[' S-measure_alpha05'][3], cat[' max-feature'][3], label='UCNet')
plt.annotate("DANet", (cat[' S-measure_alpha05'][0], cat[' max-feature'][0]))
plt.annotate("DFMNet", (cat[' S-measure_alpha05'][1], cat[' max-feature'][1]))
plt.annotate("JL-DCF", (cat[' S-measure_alpha05'][2], cat[' max-feature'][2]))
plt.annotate("UCNet", (cat[' S-measure_alpha05'][3], cat[' max-feature'][3]))
plt.ylabel("Accuracy (maxF-measure)")
plt.xlabel("Structure similarity")
plt.title("complex")
plt.grid()
plt.show()

# %%
plt.scatter(cat[' S-measure_alpha05'][0], cat[' max-feature'][0], label='DANet', s=104)
plt.scatter(cat[' S-measure_alpha05'][1], cat[' max-feature'][1], label='DFMNet', s=9)
plt.scatter(cat[' S-measure_alpha05'][2], cat[' max-feature'][2], label='JL-DCF', s=561)
plt.scatter(cat[' S-measure_alpha05'][3], cat[' max-feature'][3], label='UCNet', s=123)
# plt.scatter(cat[' S-measure_alpha05'][0], cat[' max-feature'][0], label='DANet')
# plt.scatter(cat[' S-measure_alpha05'][1], cat[' max-feature'][1], label='DFMNet')
# plt.scatter(cat[' S-measure_alpha05'][2], cat[' max-feature'][2], label='JL-DCF')
# plt.scatter(cat[' S-measure_alpha05'][3], cat[' max-feature'][3], label='UCNet')
plt.annotate("DANet", (cat[' S-measure_alpha05'][0], cat[' max-feature'][0]))
plt.annotate("DFMNet", (cat[' S-measure_alpha05'][1], cat[' max-feature'][1]))
plt.annotate("JL-DCF", (cat[' S-measure_alpha05'][2], cat[' max-feature'][2]))
plt.annotate("UCNet", (cat[' S-measure_alpha05'][3], cat[' max-feature'][3]))
plt.ylabel("Accuracy (maxF-measure)")
plt.xlabel("Structure similarity")
plt.title("Single")
plt.grid()
plt.show()

# %%
plt.scatter(cat[' S-measure_alpha05'][0], cat[' max-feature'][0], label='DANet', s=104)
plt.scatter(cat[' S-measure_alpha05'][1], cat[' max-feature'][1], label='DFMNet', s=9)
plt.scatter(cat[' S-measure_alpha05'][2], cat[' max-feature'][2], label='JL-DCF', s=561)
plt.scatter(cat[' S-measure_alpha05'][3], cat[' max-feature'][3], label='UCNet', s=123)
# plt.scatter(cat[' S-measure_alpha05'][0], cat[' max-feature'][0], label='DANet')
# plt.scatter(cat[' S-measure_alpha05'][1], cat[' max-feature'][1], label='DFMNet')
# plt.scatter(cat[' S-measure_alpha05'][2], cat[' max-feature'][2], label='JL-DCF')
# plt.scatter(cat[' S-measure_alpha05'][3], cat[' max-feature'][3], label='UCNet')
plt.annotate("DANet", (cat[' S-measure_alpha05'][0], cat[' max-feature'][0]))
plt.annotate("DFMNet", (cat[' S-measure_alpha05'][1], cat[' max-feature'][1]))
plt.annotate("JL-DCF", (cat[' S-measure_alpha05'][2], cat[' max-feature'][2]))
plt.annotate("UCNet", (cat[' S-measure_alpha05'][3] - 0.003, cat[' max-feature'][3]))
plt.ylabel("Accuracy (maxF-measure)")
plt.xlabel("Structure similarity")
plt.title("Multi")
plt.grid()
plt.show()
