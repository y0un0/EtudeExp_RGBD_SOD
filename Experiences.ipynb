# %%
# !nvidia-smi
# Out:
# Wed Dec 22 19:01:39 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    25W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# Extraction des données d'entrainement:

# %%
!7z x RGBDcollection.zip

# %%
!7z x data.zip

# %%
cd JL-DCF-pytorch

# %% [markdown]
# Si vous voulez essayez de l'entrainer voici la ligne de commande.

# %%
# !python main.py --mode=train --arch=resnet --network=resnet101 --train_root=/content/RGBDcollection --train_list=/content/RGBDcollection/train.lst

# %% [markdown]
# Test

# %%
# !python main.py --mode=test --arch=resnet --network=resnet101 --model=/content/JL-DCF-pytorch-master/models/JL-DCF_resn101.pth --test_folder=/content/pred_maps/JL-DCF/for_feat_map/
# Out:
# JL-DCF Structure
# JL_DCF(
#   (JLModule): JLModule(
#     (backbone): ResNet(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#       (layer1): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %% [markdown]
# ## UC-Net

# %%
cd UCNet/
# Out:
# /content/UCNet-master

# %%
# !python train.py
# Out:
# Generator Learning Rate: 5e-05
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 12 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='mean' instead.
#   warnings.warn(warning.format(ret))
# Let's Play!
# Generator Learning Rate: 5e-05
# 2021-12-22 09:50:05.139067 Epoch [001/101], Step [0010/0220], gen vae Loss: 5.9195, gen gsnn Loss: 8.8477, reg Loss: 0.1923
# 2021-12-22 09:50:11.743076 Epoch [001/101], Step [0020/0220], gen vae Loss: 5.1736, gen gsnn Loss: 7.7554, reg Loss: 0.1922
# ...

# %%
# !python test.py

# %% [markdown]
# ## DANet

# %%
cd DANet-RGBD-Saliency/
# Out:
# /content/DANet-RGBD-Saliency-master

# %%
# !pip install cython
# !pip install git+https://github.com/lucasb-eyer/pydensecrf.git

# %%
# !python train.py
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# [iter 15501], [total loss 0.26306],[loss1 0.04856],,[loss2 0.03604],[loss3 0.03214],[loss4 0.03034],[loss5 0.02875],[loss6 0.02893],[loss7 0.03006],[loss8 0.02823],[lr 0.0002808629991]
# [iter 15502], [total loss 0.26280],[loss1 0.04858],,[loss2 0.03600],[loss3 0.03210],[loss4 0.03029],[loss5 0.02870],[loss6 0.02887],[loss7 0.03006],[loss8 0.02821],[lr 0.0002808124432]
# [iter 15503], [total loss 0.26205],[loss1 0.04845],,[loss2 0.03590],[loss3 0.03201],[loss4 0.03021],[loss5 0.02861],[loss6 0.02878],[loss7 0.02997],[loss8 0.02813],[lr 0.0002807618864]
# [iter 15504], [total loss 0.26236],[loss1 0.04850],,[loss2 0.03593],[loss3 0.03205],[loss4 0.03025],[loss5 0.02866],[loss6 0.02882],[loss7 0.03000],[loss8 0.02815],[lr 0.0002807113285]
# ...

# %%
# Test
# !python generate_salmap.py

# %%
# Génération des cartes d'attention
# !python generate_visfeamaps.py
# Out:
# load snapshot '20500' for testing
# predicting for test: 1 / 1
# generate_visfeamaps.py:61: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   img_var = Variable(img_transform(img1).unsqueeze(0), volatile=True).cuda()
# generate_visfeamaps.py:62: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   depth = Variable(depth_transform(depth).unsqueeze(0), volatile=True).cuda()
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3509: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# ...

# %% [markdown]
# ## DFM-Net

# %%
cd DFM-Net/
# Out:
# /content/DFM-Net-main

# %%
# !python train.py
# Out:
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.6.0
# 2217335
# load data...
# Start train...
# 2021-12-16 17:38:35.324674 Epoch [001/301], Step [0001/0220], Loss1: 0.6451
# 2021-12-16 17:39:05.209451 Epoch [001/301], Step [0100/0220], Loss1: 0.4924
# 2021-12-16 17:39:36.776068 Epoch [001/301], Step [0200/0220], Loss1: 0.3710
# 2021-12-16 17:39:43.022183 Epoch [001/301], Step [0220/0220], Loss1: 0.3658
# 2021-12-16 17:39:44.042032 Epoch [002/301], Step [0001/0220], Loss1: 0.3679
# 2021-12-16 17:40:13.497604 Epoch [002/301], Step [0100/0220], Loss1: 0.3462
# 2021-12-16 17:40:44.495902 Epoch [002/301], Step [0200/0220], Loss1: 0.2693
# 2021-12-16 17:40:50.593968 Epoch [002/301], Step [0220/0220], Loss1: 0.3024
# 2021-12-16 17:40:51.698142 Epoch [003/301], Step [0001/0220], Loss1: 0.3136
# 2021-12-16 17:41:22.061662 Epoch [003/301], Step [0100/0220], Loss1: 0.3025
# 2021-12-16 17:41:53.444102 Epoch [003/301], Step [0200/0220], Loss1: 0.2566
# ...

# %%
# !python test.py

# %% [markdown]
# ## SOD eval

# %%
cd SOD_Evaluation_Metrics/
# Out:
# /content/SOD_Evaluation_Metrics

# %%
# !python main.py --pred_root_dir /content/pred_maps/ --gt_root_dir /content/gt/ --save_dir /content/score/
# Out:
# Eval [Complexbackground] Dataset [Fmeasure] with [DANet] Method.
# 100% 1400/1400 [01:23<00:00, 16.73it/s]
#
#
# Eval [Complexbackground] Dataset [MAE] with [DANet] Method.
# 100% 1400/1400 [00:09<00:00, 140.26it/s]
#
#
# Eval [Complexbackground] Dataset [Smeasure] with [DANet] Method.
# 100% 1400/1400 [00:15<00:00, 93.23it/s]
#
#
# Eval [Complexbackground] Dataset [Emeasure] with [DANet] Method.
# 100% 1400/1400 [02:51<00:00,  8.18it/s]
#
#
# Eval [Complexbackground] Dataset [Fbw_measure] with [DANet] Method.
# 100% 1400/1400 [01:36<00:00, 14.54it/s]
#
#
# [cost:376.1946s][Complexbackground Dataset] [DANet  Method] 0.0434 mae, 0.8906 max-fmeasure, 0.8653 mean-fmeasure, 0.8480 adp-fmeasure, 0.9381 max-Emeasure, 0.9240 mean-Emeasure, 0.9195 adp-Emeasure, 0.9009 S-measure_alpha05, 0.8264 Fbw-measure
#
# Eval [Complexbackground] Dataset [Fmeasure] with [DFM-Net] Method.
# 100% 1400/1400 [01:19<00:00, 17.67it/s]
#
#
# Eval [Complexbackground] Dataset [MAE] with [DFM-Net] Method.
# ...

# %%
# !python draw_curve.py

# %% [markdown]
# Sauvegarde du dossier score en .zip

# %%
# !zip -r '/content/score.zip' '/content/score/'
# Out:
#   adding: content/score/ (stored 0%)
#   adding: content/score/curve_cache/ (stored 0%)
#   adding: content/score/curve_cache/Objectscale/ (stored 0%)
#   adding: content/score/curve_cache/Objectscale/UCNet/ (stored 0%)
#   adding: content/score/curve_cache/Objectscale/UCNet/pr.txt (deflated 59%)
#   adding: content/score/curve_cache/Objectscale/UCNet/fm.txt (deflated 60%)
#   adding: content/score/curve_cache/Objectscale/DFM-Net/ (stored 0%)
#   adding: content/score/curve_cache/Objectscale/DFM-Net/pr.txt (deflated 58%)
#   adding: content/score/curve_cache/Objectscale/DFM-Net/fm.txt (deflated 59%)
#   adding: content/score/curve_cache/Objectscale/DANet/ (stored 0%)
#   adding: content/score/curve_cache/Objectscale/DANet/pr.txt (deflated 58%)
#   adding: content/score/curve_cache/Objectscale/DANet/fm.txt (deflated 59%)
#   adding: content/score/curve_cache/Objectscale/JL-DCF/ (stored 0%)
#   adding: content/score/curve_cache/Objectscale/JL-DCF/pr.txt (deflated 58%)
# ...
